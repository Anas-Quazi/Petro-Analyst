# %%
#* import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#? datasets
brent_oil = pd.read_csv('C:/Users/anasq\OneDrive/Desktop/PetroAnalyst/Dataset/brent_oil_price.csv')
wti_oil = pd.read_csv('C:/Users/anasq/OneDrive/Desktop/PetroAnalyst/Dataset/wti_crude_oil_price.csv')
lpg_price_india = pd.read_csv('C:/Users/anasq/OneDrive/Desktop/PetroAnalyst/Dataset/india_lpg_price_delhi_2010_2026.csv')


GPR_index = pd.ExcelFile(r'C:/Users/anasq/OneDrive/Desktop/PetroAnalyst/Dataset/data_gpr_export.xls')
INR_to_USD = pd.read_csv('C:/Users/anasq/OneDrive/Desktop/PetroAnalyst/Dataset/INR_to_USD.csv')
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\O'
# <>:2: SyntaxWarning: invalid escape sequence '\O'
# C:\Users\anasq\AppData\Local\Temp\ipykernel_18424\3019830651.py:2: SyntaxWarning: invalid escape sequence '\O'
#   brent_oil = pd.read_csv('C:/Users/anasq\OneDrive/Desktop/PetroAnalyst/Dataset/brent_oil_price.csv')
# C:\Users\anasq\AppData\Local\Temp\ipykernel_18424\3019830651.py:2: SyntaxWarning: invalid escape sequence '\O'
#   brent_oil = pd.read_csv('C:/Users/anasq\OneDrive/Desktop/PetroAnalyst/Dataset/brent_oil_price.csv')
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\anasq\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\compat\_optional.py:135, in import_optional_dependency(name, extra, errors, min_version)
#     134 try:
# --> 135     module = importlib.import_module(name)
#     136 except ImportError:
#
# ...
